# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_1 = pd.read_csv('../data/benin-malanville.csv')

# %%
columns_of_interest_1 = ['GHI', 'DNI', 'DHI', 'Tamb', 'TModA', 'TModB']

# %%
plt.figure(figsize=(10, 6))
data_1[columns_of_interest_1].boxplot()
plt.title('Box Plot of Solar Radiation and Temperature Data')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.show()

# %%
data_2 = pd.read_csv('./data/sierraleone-bumbuna.csv')

# %%
columns_of_interest_2 = ['GHI', 'DNI', 'DHI', 'Tamb', 'TModA', 'TModB']

# %%
plt.figure(figsize=(10, 6))
data_2[columns_of_interest_2].boxplot()
plt.title('Box Plot of Solar Radiation and Temperature Data')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.show()

# %%
data_3 = pd.read_csv('./data/togo-dapaong_qc.csv')

# %%
columns_of_interest_3 = ['GHI', 'DNI', 'DHI', 'Tamb', 'TModA', 'TModB']

# %%
plt.figure(figsize=(10, 6))
data_3[columns_of_interest_3].boxplot()
plt.title('Box Plot of Solar Radiation and Temperature Data')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.show()
